# %% [markdown]
# # Protest Classification
# ## Compare TF-IDF vs Embeddings
#
# **Goal**: Train ONE model (Random Forest Classifier) with TWO vectorization methods and compare results.
#
# **Time**: 30 minutes

# %% [markdown]
# ## Step 1: Load Data (3 minutes)

# %%
# import necessary libraries

# Load data
df = # YOUR CODE

# TODO: Combine 'notes' and 'description' into a new column 'text'. 
# You can use string concatenation with a space in between.
df['text'] = # YOUR CODE

# Quick check
print(f"Shape: {df.shape}")
print(f"\nCategories:\n{df['category'].value_counts()}")

# %%
# TODO: Encode labels into numeric labels suitable for ML models (e.g., 0, 1, 2, ...)
# use LabelEncoder from from sklearn.preprocessing import LabelEncoder
#  to transform 'category' column into numerical labels
# use fit_transform() method to generate 
# Alternatively, you can use pd.factorize() or a dictionary mapping


# YOUR CODE
y = # YOUR CODE

# TODO: Split data (80/20) using train_test_split() function from sklearn.model_selection import train_test_split
# YOUR CODE

# %% [markdown]
# ## Step 2: Model with TF-IDF (10 minutes)
#
# **What is TF-IDF?**
# - **TF** (Term Frequency): How often a word appears in a document
# - **IDF** (Inverse Document Frequency): How rare/common a word is across all documents
# - **Result**: Important words get high scores, common words (like "the") get low scores
# - **Example**: "protest" appears often in one document but not all → high TF-IDF score
#
# TF-IDF converts text into numbers that capture word importance, making it possible for ML models to work with text.
#
# 📚 **Learn more**: [TfidfVectorizer documentation](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# import other necessary libraries

# TODO: Create TF-IDF features
tfidf = TfidfVectorizer(max_features=1000)
X_train_tfidf = # YOUR CODE (fit_transform)
X_test_tfidf = # YOUR CODE (transform only)

print(f"TF-IDF shape: {X_train_tfidf.shape}")

# %%
# TODO: Train Random Forest model
# Initialize model
model_tfidf = # YOUR CODE
# YOUR CODE - fit the model

# TODO: Predict and evaluate
y_pred_tfidf = # YOUR CODE

# Calculate accuracy
acc_tfidf = # YOUR CODE


# Print results
print(f"\n TF-IDF Results:")
print(f"   Accuracy: {acc_tfidf:.4f}")

# %% [markdown]
# ## Step 3: Model with Embeddings (12 minutes)
#
# **What are Sentence Embeddings?**
# - Convert entire sentences/paragraphs into dense vectors (fixed-size arrays of numbers)
# - Capture **semantic meaning**: "protest rally" and "demonstration" will have similar vectors
# - Pre-trained on huge datasets, so they understand context and synonyms
# - **all-MiniLM-L6-v2**: Lightweight model (384 dimensions, fast, good quality)
#
# **Key difference from TF-IDF:**
# - TF-IDF: Word frequency only → "protest" and "demonstration" are completely different
# - Embeddings: Semantic meaning → "protest" and "demonstration" are similar
#
# 📚 **Learn more**: [Sentence Transformers documentation](https://www.sbert.net/docs/pretrained_models.html)

# %%
import os
import subprocess

input_folder = "/Users/dmatekenya/Desktop/response-statement-final/fathers-medical-records-expenses"
output_folder = "/Users/dmatekenya/Desktop/response-statement-final/tmp"
os.makedirs(output_folder, exist_ok=True)

for file in os.listdir(input_folder):
    if file.lower().endswith(".pdf"):
        input_path = os.path.join(input_folder, file)
        output_path = os.path.join(output_folder, file)
        subprocess.run([
            "gs",
            "-sDEVICE=pdfwrite",
            "-dCompatibilityLevel=1.4",
            "-dPDFSETTINGS=/ebook",  # Options: /screen (smallest), /ebook (medium), /printer (high)
            "-dNOPAUSE",
            "-dQUIET",
            "-dBATCH",
            f"-sOutputFile={output_path}",
            input_path
        ])
        print(f"Compressed: {file}")
# Out:
# Compressed: hospital-visit-sept2-2025.pdf
# Compressed: hospital-visit-jan1-2025.pdf
# Compressed: hospital-visit-no-date2.pdf
# Compressed: hospital-visit-2023.pdf
# Compressed: surgery-daeyang-hospital-2022.pdf
# Compressed: hospital-visit-no-date3.pdf
# Compressed: hospital-visit-sept-2025.pdf
# Compressed: surgical-review-november-2023-daeyang.pdf
# Compressed: diagnostics-receipts2.pdf
# Compressed: diagnostics-receipts3.pdf
# Compressed: Mr. Matekenya Radiology Report.pdf
# Compressed: hospital-visit-no-date6.pdf
# Compressed: hospital-visit-no-date.pdf
# Compressed: hospital-visit-no-date4.pdf
# Compressed: surgery-daeyang-hospital-oct-2023.pdf
# Compressed: diagnostics-receipts.pdf
# Compressed: hospital-visit-july-2023.pdf
# Compressed: Electronic ticket receipt, October 14 for DR DUNSTAN MATEKENYA.pdf
# Compressed: hospital-visit-july-2025.pdf
# Compressed: surgery-check-2-2022.pdf
# Compressed: hospital-visit-oct-nov-2025.pdf
# Compressed: hospital-visit-sept13-2025.pdf
# Compressed: surgey-check-daeyang-nov-2023.pdf
# Compressed: hospital-visit-nodate5.pdf
# Compressed: surgery-notes-no-date.pdf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 12
#      10 input_path = os.path.join(input_folder, file)
#      11 output_path = os.path.join(output_folder, file)
# ---> 12 subprocess.run([
#      13     "gs",
#      14     "-sDEVICE=pdfwrite",
#      15     "-dCompatibilityLevel=1.4",
#      16     "-dPDFSETTINGS=/ebook",  # Options: /screen (smallest), /ebook (medium), /printer (high)
#      17     "-dNOPAUSE",
#      18     "-dQUIET",
#      19     "-dBATCH",
#      20     f"-sOutputFile={output_path}",
#      21     input_path
#      22 ])
#      23 print(f"Compressed: {file}")
#
# File ~/anaconda3/lib/python3.12/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File ~/anaconda3/lib/python3.12/subprocess.py:1201, in Popen.communicate(self, input, timeout)
#    1199         stderr = self.stderr.read()
#    1200         self.stderr.close()
# -> 1201     self.wait()
#    1202 else:
#    1203     if timeout is not None:
#
# File ~/anaconda3/lib/python3.12/subprocess.py:1264, in Popen.wait(self, timeout)
#    1262     endtime = _time() + timeout
#    1263 try:
# -> 1264     return self._wait(timeout=timeout)
#    1265 except KeyboardInterrupt:
#    1266     # https://bugs.python.org/issue25942
#    1267     # The first keyboard interrupt waits briefly for the child to
#    1268     # exit under the common assumption that it also received the ^C
#    1269     # generated SIGINT and will exit rapidly.
#    1270     if timeout is not None:
#
# File ~/anaconda3/lib/python3.12/subprocess.py:2053, in Popen._wait(self, timeout)
#    2051 if self.returncode is not None:
#    2052     break  # Another thread waited.
# -> 2053 (pid, sts) = self._try_wait(0)
#    2054 # Check the pid and loop as waitpid has been known to
#    2055 # return 0 even without WNOHANG in odd situations.
#    2056 # http://bugs.python.org/issue14396.
#    2057 if pid == self.pid:
#
# File ~/anaconda3/lib/python3.12/subprocess.py:2011, in Popen._try_wait(self, wait_flags)
#    2009 """All callers to this function MUST hold self._waitpid_lock."""
#    2010 try:
# -> 2011     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2012 except ChildProcessError:
#    2013     # This happens if SIGCLD is set to be ignored or waiting
#    2014     # for child processes has otherwise been disabled for our
#    2015     # process.  This child is dead, we can't get the status.
#    2016     pid = self.pid
#
# KeyboardInterrupt:

# %%
from sentence_transformers import SentenceTransformer

# TODO: Load embedding model
print("Loading embedding model...")
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

# TODO: Encode training data to get embeddings
print("\nEncoding training data (this takes ~1 minute)...")
X_train_embed = # YOUR CODE (use .encode())

# TODO: Encode test data to get embeddings
print("Encoding test data...")
X_test_embed = # YOUR CODE

print(f"\nEmbedding shape: {X_train_embed.shape}")

# %%
# TODO: Train same model with embeddings
model_embed = # YOUR CODE
# YOUR CODE - fit the model

# TODO: Predict and evaluate
y_pred_embed = # YOUR CODE
acc_embed = 
hh

print(f"\nEmbeddings Results:")
print(f"   Accuracy: {acc_embed:.4f}")

# %% [markdown]
# ## Step 4: Compare Results (5 minutes)

# %%
# TODO: Create comparison table
# Create a DataFrame to compare results
# one column for method, one for accuracy
results = # YOUR CODE

print("\n" + "="*60)
print("FINAL COMPARISON")
print("="*60)
print(results.to_string(index=False))
print("="*60)
